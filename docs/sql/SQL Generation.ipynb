# %%
#r "nuget: Jinaga"
#r "nuget: Jinaga.UnitTest"
#r "nuget: Jinaga.Graphviz"
using Jinaga;
using Jinaga.UnitTest;
using Jinaga.Graphviz;

var j = JinagaClient.Create();
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Jinaga, 0.3.0</span></li><li><span>Jinaga.Graphviz, 0.3.0</span></li><li><span>Jinaga.UnitTest, 0.3.0</span></li></ul></div></div>

# %% [markdown]
# # SQL Generation
#
# The Jinaga specification language describes a walk through a graph of facts.
# To execute this walk, Jinaga needs to generate SQL queries.
# We'll examine some incrementally more complicated queries to see how Jinaga generates SQL.
#
# ## Specifications
#
# To understand how Jinaga generates SQL, we need to understand Jinaga specifications.
# Let's start with a model of a school offering courses.

# %%
[FactType("School")]
public record School(string name) {}

[FactType("Course")]
public record Course(School school, string identifier) {}

Renderer.RenderTypes(typeof(School), typeof(Course))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="98pt" height="131pt"
#  viewBox="0.00 0.00 97.55 131.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 127)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-127 93.55,-127 93.55,4 -4,4"/>
# <!-- Course -->
# <g id="node1" class="node">
# <title>Course</title>
# <ellipse fill="none" stroke="black" cx="43.55" cy="-18" rx="43.59" ry="18"/>
# <text text-anchor="middle" x="43.55" y="-14.3" font-family="Times,serif" font-size="14.00">Course</text>
# </g>
# <!-- School -->
# <g id="node2" class="node">
# <title>School</title>
# <ellipse fill="none" stroke="black" cx="43.55" cy="-105" rx="41.69" ry="18"/>
# <text text-anchor="middle" x="43.55" y="-101.3" font-family="Times,serif" font-size="14.00">School</text>
# </g>
# <!-- Course&#45;&gt;School -->
# <g id="edge1" class="edge">
# <title>Course&#45;&gt;School</title>
# <path fill="none" stroke="black" d="M43.55,-36.2C43.55,-47.84 43.55,-63.45 43.55,-76.76"/>
# <polygon fill="black" stroke="black" points="40.05,-76.82 43.55,-86.82 47.05,-76.82 40.05,-76.82"/>
# <text text-anchor="middle" x="66.55" y="-57.8" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# Suppose that the model contained the following facts.

# %%
var lps = await j.Fact(new School("LPS Frisco"));
var algebra = await j.Fact(new Course(lps, "MATH 101"));
var geometry = await j.Fact(new Course(lps, "MATH 102"));
var trigonometry = await j.Fact(new Course(lps, "MATH 201"));
var calculus = await j.Fact(new Course(lps, "MATH 301"));

Renderer.RenderFacts(algebra, geometry, trigonometry, calculus)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="750pt" height="161pt"
#  viewBox="0.00 0.00 750.00 161.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 157)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-157 746,-157 746,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="306,-128 306,-149 436,-149 436,-128 306,-128"/>
# <text text-anchor="start" x="347" y="-134.8" font-family="Times,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="306,-107 306,-128 352,-128 352,-107 306,-107"/>
# <text text-anchor="start" x="309" y="-113.8" font-family="Times,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="352,-107 352,-128 436,-128 436,-107 352,-107"/>
# <text text-anchor="start" x="355" y="-113.8" font-family="Times,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="9,-26 9,-47 163,-47 163,-26 9,-26"/>
# <text text-anchor="start" x="60.5" y="-32.8" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="9,-5 9,-26 81,-26 81,-5 9,-5"/>
# <text text-anchor="start" x="12" y="-11.8" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="81,-5 81,-26 163,-26 163,-5 81,-5"/>
# <text text-anchor="start" x="84" y="-11.8" font-family="Times,serif" font-size="14.00">MATH 101</text>
# <polygon fill="none" stroke="black" points="8,-4 8,-48 164,-48 164,-4 8,-4"/>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M157.55,-52.11C198.7,-66.54 250.45,-84.7 292.68,-99.52"/>
# <polygon fill="black" stroke="black" points="291.78,-102.91 302.37,-102.92 294.09,-96.31 291.78,-102.91"/>
# <text text-anchor="middle" x="269" y="-73.8" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg== -->
# <g id="node3" class="node">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==</title>
# <polygon fill="none" stroke="black" points="199,-26 199,-47 353,-47 353,-26 199,-26"/>
# <text text-anchor="start" x="250.5" y="-32.8" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="199,-5 199,-26 271,-26 271,-5 199,-5"/>
# <text text-anchor="start" x="202" y="-11.8" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="271,-5 271,-26 353,-26 353,-5 271,-5"/>
# <text text-anchor="start" x="274" y="-11.8" font-family="Times,serif" font-size="14.00">MATH 102</text>
# <polygon fill="none" stroke="black" points="198,-4 198,-48 354,-48 354,-4 198,-4"/>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge2" class="edge">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M299.97,-52.23C312.4,-65.32 327.71,-81.43 340.92,-95.34"/>
# <polygon fill="black" stroke="black" points="338.59,-97.97 348.02,-102.81 343.67,-93.15 338.59,-97.97"/>
# <text text-anchor="middle" x="353" y="-73.8" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="node4" class="node">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <polygon fill="none" stroke="black" points="389,-26 389,-47 543,-47 543,-26 389,-26"/>
# <text text-anchor="start" x="440.5" y="-32.8" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="389,-5 389,-26 461,-26 461,-5 389,-5"/>
# <text text-anchor="start" x="392" y="-11.8" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="461,-5 461,-26 543,-26 543,-5 461,-5"/>
# <text text-anchor="start" x="464" y="-11.8" font-family="Times,serif" font-size="14.00">MATH 201</text>
# <polygon fill="none" stroke="black" points="388,-4 388,-48 544,-48 544,-4 388,-4"/>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge3" class="edge">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M442.03,-52.23C429.6,-65.32 414.29,-81.43 401.08,-95.34"/>
# <polygon fill="black" stroke="black" points="398.33,-93.15 393.98,-102.81 403.41,-97.97 398.33,-93.15"/>
# <text text-anchor="middle" x="448" y="-73.8" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- kx9coOGM5rOjFI9dxNAsrNU1l9oQzEjeszW43KlFqoGxKZ3+G7oqTZAVZjhzXMB+oL6RTF0TDBRQjRhAqg7WlQ== -->
# <g id="node5" class="node">
# <title>kx9coOGM5rOjFI9dxNAsrNU1l9oQzEjeszW43KlFqoGxKZ3+G7oqTZAVZjhzXMB+oL6RTF0TDBRQjRhAqg7WlQ==</title>
# <polygon fill="none" stroke="black" points="579,-26 579,-47 733,-47 733,-26 579,-26"/>
# <text text-anchor="start" x="630.5" y="-32.8" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="579,-5 579,-26 651,-26 651,-5 579,-5"/>
# <text text-anchor="start" x="582" y="-11.8" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="651,-5 651,-26 733,-26 733,-5 651,-5"/>
# <text text-anchor="start" x="654" y="-11.8" font-family="Times,serif" font-size="14.00">MATH 301</text>
# <polygon fill="none" stroke="black" points="578,-4 578,-48 734,-48 734,-4 578,-4"/>
# </g>
# <!-- kx9coOGM5rOjFI9dxNAsrNU1l9oQzEjeszW43KlFqoGxKZ3+G7oqTZAVZjhzXMB+oL6RTF0TDBRQjRhAqg7WlQ==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge4" class="edge">
# <title>kx9coOGM5rOjFI9dxNAsrNU1l9oQzEjeszW43KlFqoGxKZ3+G7oqTZAVZjhzXMB+oL6RTF0TDBRQjRhAqg7WlQ==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M584.45,-52.11C543.3,-66.54 491.55,-84.7 449.32,-99.52"/>
# <polygon fill="black" stroke="black" points="447.91,-96.31 439.63,-102.92 450.22,-102.91 447.91,-96.31"/>
# <text text-anchor="middle" x="553" y="-73.8" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# Write a query to return the catalog of courses offered by the school.

# %%
var coursesInSchool = Given<School>.Match((school, facts) =>
  from course in facts.OfType<Course>()
  where course.school == school
  select course
);

var catalog = await j.Query(lps, coursesInSchool);
catalog
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 101 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 101</td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 102 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 102</td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 201 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 201</td></tr></tbody></table></div></details></td></tr><tr><td>3</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 301 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 301</td></tr></tbody></table></div></details></td></tr></tbody></table><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# This query can be expressed using the Jinaga specification language.

# %%
coursesInSchool.ToDescriptiveString()
# Out:
# (school: School) {
#     course: Course [
#         course->school: School = school
#     ]
# } => course

# %% [markdown]
# Within the Jinaga runtime, this specification is represented as a data structure.
# A specification has three parts:
# - Given
# - Matches
# - Projection
#
# The `given` is a collection of labels that are placeholders for known facts.
# In this particular specification, the given is the label `school` of type `School`.
#
# ```
# (school: School)
# ```
#
# The `matches` collection contains a set of labels for unknown facts, and their corresponding conditions.
# This specification has a single match, which has the label `course` of type `Course`.
# The condition is that the course `school` is the same as the given `school`.
#
# ```
# course: Course [
#   course->school: School = school
# ]
# ```
#
# The collection of unknowns declared in the matches form a tuple.
# That is to say that when the specification is run, the result is the set of all tuples that simultaneously satisfy the conditions.
# In this case, there is only one unknown.
# Each tuple therefore contains a single fact.
#
# ```javascript
# [
#   { course: algebra },
#   { course: geometry },
#   { course: trigonometry },
#   { course: calculus }
# ]
# ```
#
# The `projection` is a function that takes a tuple and returns a value.
# In this case, the projection is a function that returns the `course` fact.
#
# ```
# => course
# ```
#
# The result is therefore a set of facts.
#
# ```javascript
# [
#   algebra,
#   geometry,
#   trigonometry,
#   calculus
# ]
# ```

# %% [markdown]
# ### Feed
#
# Jinaga runs two different kinds of SQL queries to satisfy a specification.
# The first is a feed query.
# A feed query returns the tuples that satisfy the specification.
# It does not run the projection function.
#
# To run the feed query, Jinaga first builds a Query Description.
# The Query Description has five parts:
# - Inputs
# - Parameters
# - Outputs
# - Edges
# - Not exists conditions
#
# The `inputs` are the given facts.
# They represent the `given` labels in the specification.
# They also record a specific fact instance for each of those labels.
# In the example above, the input is the `school` fact "LPS Frisco".
#
# For each input, Jinaga allocates a join to the fact table.
# It doesn't turn these into SQL immediately.
# Instead, it simply reserves an index.
#
# It also allocates two parameters.
# The first is for the fact type, and the second is for the fact hash.
# It stores the parameters in a parallel collection called `parameters`, and keeps the indices in the `inputs` collection.
#
# For the example query, the resulting `inputs` and `parameters` arrays are as follows.
# The number 1001 would be the ID of the fact type `School`.
# The string "XYZ123" would be the hash of the "LPS Frisco" fact instance.
#
# ```javascript
# inputs: [
#   {
#     factIndex: 1,
#     factTypeParameter: 1,
#     factHashParameter: 2
#   }
# ]
#
# parameters: [
#   1001,
#   "XYZ123"
# ]
# ```
#
# Next Jinaga builds the `edges` collection.
# An edge description represents a relationship between two labels.
# In the example above, there is a single edge.
# It connects the unknown `course` to the given `school`.
#
# To build the edges, Jinaga walks the join conditions within the matches.
# For each step, it allocates a join to both the fact table and the edge table.
# In the above example, it allocates fact index 2 to the `course` label and edge index 1 to the step from course to school.
#
# It also allocates one parameter for each edge join.
# That parameter is for the role.
#
# For the example query, the resulting `edges` and `parameters` arrays are as follows.
# The number 2001 would be the ID of the fact type `Course`.
#
# ```javascript
# edges: [
#   {
#     edgeIndex: 1,
#     predecessorIndex: 1,
#     successorIndex: 2,
#     roleParameter: 3
#   }
# ]
#
# parameters: [
#   1001,
#   "XYZ123",
#   2001
# ]
# ```
#
# The `outputs` are the unknowns.
# For each of these, Jinaga records the index of the fact table join.
#
# For the example query, the resulting `outputs` array is as follows.
# The fact index 2 was allocated to the `course` label.
#
# ```javascript
# outputs: [
#   {
#     factIndex: 2
#   }
# ]
# ```
#
# We'll examine the `not exists` conditions later.
# They do not apply to this example.

# %% [markdown]
# ### Feed SQL
#
# Now that Jinaga has built the Query Description, it can turn it into SQL.
# The `SELECT` clause is based on the `outputs` collection.
# For each output, Jinaga adds a column for the fact hash.
#
# It also selects a sorted array of fact IDs as the bookmark.
# The bookmark is a decreasing list of the fact IDs in the tuple.
# The bookmark will also appear at the end of the generated SQL for paging and sorting.
#
# ```sql
# SELECT
#   f2.hash as hash2,
#   sort(array[f2.fact_id], 'desc') as bookmark
# ```
#
# Then it generates the `FROM` clause using the first fact index.
#
# ```sql
# FROM fact f1  -- school
# ```
#
# Then it generates the `WHERE` clause.
# To do so, it iterates through the `edges` collection.
# It makes sure that at least one of the fact indexes -- the predecessor or successor -- has already been written.
# Then it writes out the edge join and the remaining fact join.
# Here it uses the edge role parameter.
#
# ```sql
# JOIN edge e1  -- course -> school
#   ON e1.predecessor_fact_id = f1.fact_id
#   AND e1.role_id = $3
# JOIN fact f2  -- course
#   ON f2.fact_id = e1.successor_fact_id
# ```
#
# Next it generates the `WHERE` clause for the `inputs`.
# It uses the fact type and fact hash parameters.
# It includes the bookmark in the where clause to continue reading the feed from the point that the previous page ended.
#
# ```sql
# WHERE f1.fact_type_id = $1 AND f1.hash = $2
#   AND sort(array[f2.fact_id], 'desc') > $4
# ```
#
# Finally, it sorts and pages the results using the bookmark.
#
# ```sql
# ORDER BY bookmark ASC LIMIT $5
# ```
#
# The resulting SQL is as follows:
#
# ```sql
# SELECT
#   f2.hash as hash2,
#   sort(array[f2.fact_id], 'desc') as bookmark
# FROM fact f1  -- school
# JOIN edge e1  -- course -> school
#   ON e1.predecessor_fact_id = f1.fact_id
#   AND e1.role_id = $3
# JOIN fact f2  -- course
#   ON f2.fact_id = e1.successor_fact_id
# WHERE f1.fact_type_id = $1 AND f1.hash = $2
#   AND sort(array[f2.fact_id], 'desc') > $4
# ORDER BY bookmark ASC LIMIT $5
# ```

# %% [markdown]
# ### Result SQL
#
# The Feed SQL query is intended to fetch tuples a page at a time.
# It is executed on the server.
# The Result SQL query, on the other hand, is intended to fetch the results of the projection function.
# It is executed on the client.
# The one exception is the `/read` endpoint, which runs the projection on the server for human consumption.
#
# The Result SQL query is more complex than the Feed SQL query.
# It can contain nested existential queries to any depth.
# This simple example does not contain any existential queries, so the differences are less significant.
#
# The `inputs` and `outputs` collections differ from the Feed SQL generator in that they also contain the labels.
# For the example query, the `inputs` and `outputs` collections are as follows.
#
# ```javascript
# inputs: [
#   {
#     label: "school",
#     factIndex: 1,
#     factTypeParameter: 1,
#     factHashParameter: 2
#   }
# ]
#
# outputs: [
#   {
#     label: "course",
#     factIndex: 2
#   }
# ]
# ```
#
# This extra information helps the result composer to execute the projection function.
# The composer will need the field values of the facts, which are in the `data` column.
# It will also need the fact IDs to link child projections to their parents.
# It therefore adds those columns to the `SELECT` clause.
#
# ```sql
# SELECT
#   f2.hash as hash2, f2.fact_id as id2, f2.data as data2
# ```
#
# Then it generates the `FROM`, `JOIN`, and `WHERE` clauses as before.
# The Result SQL, however, does not include the bookmark in the `WHERE` clause.
#
# ```sql
# FROM fact f1  -- school
# JOIN edge e1  -- course -> school
#   ON e1.predecessor_fact_id = f1.fact_id
#   AND e1.role_id = $3
# JOIN fact f2  -- course
#   ON f2.fact_id = e1.successor_fact_id
# WHERE f1.fact_type_id = $1 AND f1.hash = $2
# ```
#
# The Result SQL is not sorted by bookmark.
# Instead, it is sorted by the fact ID.
#
# ```sql
# ORDER BY f2.fact_id ASC
# ```
#
# The resulting SQL is as follows:
#
# ```sql
# SELECT
#   f2.hash as hash2, f2.fact_id as id2, f2.data as data2
# FROM fact f1
# JOIN edge e1
#   ON e1.predecessor_fact_id = f1.fact_id
#   AND e1.role_id = $3
# JOIN fact f2
#   ON f2.fact_id = e1.successor_fact_id
# WHERE f1.fact_type_id = $1 AND f1.hash = $2
# ORDER BY f2.fact_id ASC
# ```

# %% [markdown]
# ## Existential Conditions
#
# Any realistic specification in a Jinaga application will likely contain an existential condition, often a negative one.
# A negative existential condition discards results based on certain successors.
# For example, a specification might discard courses that have been deleted.

# %%
[FactType("Course.Deleted")]
public record CourseDeleted(Course course, DateTime deletedAt) {}

Renderer.RenderTypes(typeof(CourseDeleted))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="173pt" height="218pt"
#  viewBox="0.00 0.00 173.09 218.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 214)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-214 169.09,-214 169.09,4 -4,4"/>
# <!-- Course.Deleted -->
# <g id="node1" class="node">
# <title>Course.Deleted</title>
# <ellipse fill="none" stroke="black" cx="82.54" cy="-18" rx="82.59" ry="18"/>
# <text text-anchor="middle" x="82.54" y="-14.3" font-family="Times,serif" font-size="14.00">Course.Deleted</text>
# </g>
# <!-- Course -->
# <g id="node2" class="node">
# <title>Course</title>
# <ellipse fill="none" stroke="black" cx="82.54" cy="-105" rx="43.59" ry="18"/>
# <text text-anchor="middle" x="82.54" y="-101.3" font-family="Times,serif" font-size="14.00">Course</text>
# </g>
# <!-- Course.Deleted&#45;&gt;Course -->
# <g id="edge1" class="edge">
# <title>Course.Deleted&#45;&gt;Course</title>
# <path fill="none" stroke="black" d="M82.54,-36.2C82.54,-47.84 82.54,-63.45 82.54,-76.76"/>
# <polygon fill="black" stroke="black" points="79.04,-76.82 82.54,-86.82 86.04,-76.82 79.04,-76.82"/>
# <text text-anchor="middle" x="106.54" y="-57.8" font-family="Times,serif" font-size="14.00">course</text>
# </g>
# <!-- School -->
# <g id="node3" class="node">
# <title>School</title>
# <ellipse fill="none" stroke="black" cx="82.54" cy="-192" rx="41.69" ry="18"/>
# <text text-anchor="middle" x="82.54" y="-188.3" font-family="Times,serif" font-size="14.00">School</text>
# </g>
# <!-- Course&#45;&gt;School -->
# <g id="edge2" class="edge">
# <title>Course&#45;&gt;School</title>
# <path fill="none" stroke="black" d="M82.54,-123.2C82.54,-134.84 82.54,-150.45 82.54,-163.76"/>
# <polygon fill="black" stroke="black" points="79.04,-163.82 82.54,-173.82 86.04,-163.82 79.04,-163.82"/>
# <text text-anchor="middle" x="105.54" y="-144.8" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# If the school wishes to no longer offer Trigonometry, then it would represent that with a course deletion fact.

# %%
var trigonometryDeleted = await j.Fact(new CourseDeleted(trigonometry, DateTime.Now));

Renderer.RenderFacts(algebra, geometry, trigonometryDeleted, calculus)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="748pt" height="264pt"
#  viewBox="0.00 0.00 748.00 264.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 260)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-260 744,-260 744,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="275,-231 275,-252 405,-252 405,-231 275,-231"/>
# <text text-anchor="start" x="316" y="-237.8" font-family="Times,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="275,-210 275,-231 321,-231 321,-210 275,-210"/>
# <text text-anchor="start" x="278" y="-216.8" font-family="Times,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="321,-210 321,-231 405,-231 405,-210 321,-210"/>
# <text text-anchor="start" x="324" y="-216.8" font-family="Times,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="9,-129 9,-150 163,-150 163,-129 9,-129"/>
# <text text-anchor="start" x="60.5" y="-135.8" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="9,-108 9,-129 81,-129 81,-108 9,-108"/>
# <text text-anchor="start" x="12" y="-114.8" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="81,-108 81,-129 163,-129 163,-108 81,-108"/>
# <text text-anchor="start" x="84" y="-114.8" font-family="Times,serif" font-size="14.00">MATH 101</text>
# <polygon fill="none" stroke="black" points="8,-107 8,-151 164,-151 164,-107 8,-107"/>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M149.77,-155.11C186.21,-169.45 231.98,-187.47 269.49,-202.24"/>
# <polygon fill="black" stroke="black" points="268.25,-205.51 278.84,-205.92 270.81,-199 268.25,-205.51"/>
# <text text-anchor="middle" x="252" y="-176.8" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg== -->
# <g id="node3" class="node">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==</title>
# <polygon fill="none" stroke="black" points="199,-129 199,-150 353,-150 353,-129 199,-129"/>
# <text text-anchor="start" x="250.5" y="-135.8" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="199,-108 199,-129 271,-129 271,-108 199,-108"/>
# <text text-anchor="start" x="202" y="-114.8" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="271,-108 271,-129 353,-129 353,-108 271,-108"/>
# <text text-anchor="start" x="274" y="-114.8" font-family="Times,serif" font-size="14.00">MATH 102</text>
# <polygon fill="none" stroke="black" points="198,-107 198,-151 354,-151 354,-107 198,-107"/>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge2" class="edge">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M292.15,-155.23C300.29,-167.95 310.26,-183.54 318.99,-197.18"/>
# <polygon fill="black" stroke="black" points="316.18,-199.27 324.52,-205.81 322.07,-195.5 316.18,-199.27"/>
# <text text-anchor="middle" x="335" y="-176.8" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="node4" class="node">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <polygon fill="none" stroke="black" points="388,-129 388,-150 542,-150 542,-129 388,-129"/>
# <text text-anchor="start" x="439.5" y="-135.8" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="388,-108 388,-129 460,-129 460,-108 388,-108"/>
# <text text-anchor="start" x="391" y="-114.8" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="460,-108 460,-129 542,-129 542,-108 460,-108"/>
# <text text-anchor="start" x="463" y="-114.8" font-family="Times,serif" font-size="14.00">MATH 201</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge3" class="edge">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M434.74,-154.21C417.82,-167.74 396.57,-184.75 378.48,-199.22"/>
# <polygon fill="black" stroke="black" points="376.04,-196.69 370.41,-205.67 380.41,-202.16 376.04,-196.69"/>
# <text text-anchor="middle" x="433" y="-176.8" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- 2WJIRJpw/Jlyydtvqo5g6oKRoJKnZl7l+3kmREeA3Bz4sv0i9e9kT/81T3W6NrwWe5NZseJYa4R9Gh5Qd9RL2A== -->
# <g id="node5" class="node">
# <title>2WJIRJpw/Jlyydtvqo5g6oKRoJKnZl7l+3kmREeA3Bz4sv0i9e9kT/81T3W6NrwWe5NZseJYa4R9Gh5Qd9RL2A==</title>
# <polygon fill="none" stroke="black" points="327,-26 327,-47 604,-47 604,-26 327,-26"/>
# <text text-anchor="start" x="410" y="-32.8" font-family="Times,serif" font-size="14.00">Course.Deleted</text>
# <polygon fill="none" stroke="black" points="327,-5 327,-26 403,-26 403,-5 327,-5"/>
# <text text-anchor="start" x="330" y="-11.8" font-family="Times,serif" font-size="14.00">deletedAt</text>
# <polygon fill="none" stroke="black" points="403,-5 403,-26 604,-26 604,-5 403,-5"/>
# <text text-anchor="start" x="406" y="-11.8" font-family="Times,serif" font-size="14.00">2023&#45;04&#45;02T19:20:11.145Z</text>
# <polygon fill="none" stroke="black" points="325.5,-4 325.5,-48 604.5,-48 604.5,-4 325.5,-4"/>
# </g>
# <!-- 2WJIRJpw/Jlyydtvqo5g6oKRoJKnZl7l+3kmREeA3Bz4sv0i9e9kT/81T3W6NrwWe5NZseJYa4R9Gh5Qd9RL2A==&#45;&gt;T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="edge4" class="edge">
# <title>2WJIRJpw/Jlyydtvqo5g6oKRoJKnZl7l+3kmREeA3Bz4sv0i9e9kT/81T3W6NrwWe5NZseJYa4R9Gh5Qd9RL2A==&#45;&gt;T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <path fill="none" stroke="black" d="M465,-52.23C465,-64.67 465,-79.88 465,-93.4"/>
# <polygon fill="black" stroke="black" points="461.5,-93.79 465,-103.79 468.5,-93.79 461.5,-93.79"/>
# <text text-anchor="middle" x="489" y="-73.8" font-family="Times,serif" font-size="14.00">course</text>
# </g>
# <!-- kx9coOGM5rOjFI9dxNAsrNU1l9oQzEjeszW43KlFqoGxKZ3+G7oqTZAVZjhzXMB+oL6RTF0TDBRQjRhAqg7WlQ== -->
# <g id="node

# %% [markdown]
# We can revise the specification to return only courses that have not been deleted.

# %%
var coursesInSchoolNotDeleted = Given<School>.Match((school, facts) =>
  from course in facts.OfType<Course>()
  where course.school == school
  where !facts.OfType<CourseDeleted>(deleted => deleted.course == course).Any()
  select course
);

coursesInSchoolNotDeleted.ToDescriptiveString()
# Out:
# (school: School) {
#     course: Course [
#         course->school: School = school
#         !E {
#             deleted: Course.Deleted [
#                 deleted->course: Course = course
#             ]
#         }
#     ]
# } => course

# %% [markdown]
# When we run this specification for the school "LPS Frisco", we get back the three courses that have not been deleted.

# %%
var catalogNotDeleted = await j.Query(lps, coursesInSchoolNotDeleted);

catalogNotDeleted
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 101 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 101</td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 102 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 102</td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 301 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 301</td></tr></tbody></table></div></details></td></tr></tbody></table><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# ### Feeds with Existential Conditions
#
# Existential conditions affect feeds differently than they affect results.
# The reason is that a negative existential condition *removes* results.
# The fact that *caused* the deletion is not returned.
#
# To rectify this issue, a specification with a negative existential condition produces an additional feed.
# This feed includes the facts that caused the deletion.
# For this example, the feed returns the tuple of course and deletion.

# %%
Given<School>.Match((school, facts) =>
  from course in facts.OfType<Course>()
  where course.school == school
  from deleted in facts.OfType<CourseDeleted>()
  where deleted.course == course
  select new { course, deleted }
).ToDescriptiveString()
# Out:
# (school: School) {
#     course: Course [
#         course->school: School = school
#     ]
#     deleted: Course.Deleted [
#         deleted->course: Course = course
#     ]
# } => {
#     course = course
#     deleted = deleted
# }

# %% [markdown]
# Generating SQL for this feed is no different than the example we saw earlier.
# It simply traverses two edges instead of one.
# But generating SQL for the other feed brings in one additional step.
# It must generate a `NOT EXISTS` clause for the existential condition.
#
# As was mentioned before, the Query Description contains `not exists` condition descriptions.
# Each one contains a list of `edges`.
# The example of deleting a course introduces one `not exists` condition having one edge.
#
# Jinaga allocates a second edge for the `not exists` condition.
# This represents the connection between the `course` label (fact index 2) and the newly allocated `deleted` label (fact index 3).
# It also allocates a parameter (index 4) for the role of the edge.
# The resulting clause is as follows.
#
# ```javascript
# notExists: [
#   {
#     edges: [
#       {
#         edgeIndex: 2,
#         predecessorFactIndex: 2,
#         roleParameter: 4,
#         successorFactIndex: 3
#       }
#     ]
#   }
# ]
# ```
#
# To turn the `notExists` condition into SQL, Jinaga generates a `NOT EXISTS` condition within the `WHERE` clause.
# It connects the condition to the outer query using a `WHERE` clause.
#
# ```sql
# AND NOT EXISTS (
#   SELECT 1
#   FROM edge e2  -- deleted -> course
#   JOIN fact f3  -- deleted
#     ON f3.fact_id = e2.successor_fact_id
#   WHERE e2.predecessor_fact_id = f2.fact_id
#     AND e2.role_id = $4
# )
# ```
#
# The rest of the SQL generation is the same as before.
# The resulting SQL is as follows:
#
# ```sql
# SELECT
#   f2.hash as hash2,
#   sort(array[f2.fact_id], 'desc') as bookmark
# FROM fact f1  -- school
# JOIN edge e1  -- course -> school
#   ON e1.predecessor_fact_id = f1.fact_id
#   AND e1.role_id = $3
# JOIN fact f2  -- course
#   ON f2.fact_id = e1.successor_fact_id
# WHERE
#   f1.fact_type_id = $1 AND f1.hash = $2
#   AND NOT EXISTS (
#     SELECT 1
#     FROM edge e2  -- deleted -> course
#     JOIN fact f3  -- deleted
#       ON f3.fact_id = e2.successor_fact_id
#     WHERE e2.predecessor_fact_id = f2.fact_id
#       AND e2.role_id = $4)
#   AND sort(array[f2.fact_id], 'desc') > $5
# ORDER BY bookmark ASC LIMIT $6
# ```
#
# A feed does not contain nested existential conditions.
# A nested existential condition usually represents undoing a previous deletion.
# If the feed executed those nested conditions, then tuples would be re-inserted into the middle of a feed when the deletion was undone.
# This would violate the feed's integrity.
# A client that had already read past the point of re-insertion would never see the re-inserted tuples.
#
# The solution instead is to generate a separate feed for each nested existential condition.
# This would result in three separate feeds: one for the courses, one for the deletions, and one to undo deletions.

# %% [markdown]
# ### Results with Existential Conditions
#
# Results queries differ from feed queries in two ways as it relates to existential conditions.
# First, they apply both positive and negative conditions.
# Second, they allow nesting of existential conditions to any depth.
#
# Since results execute both positive and negative conditions, the `notExists` list is instead called `existentialConditions`.
# Each element contains a flag called `exists` indicating whether the condition is positive or negative.
#
# Then to accommodate nesting, each existential condition definition contains both edges and a child `existentialConditions` list.
# In this particular scenario, the child list is empty.
#
# ```javascript
# existentialConditions: [
#   {
#     exists: false,
#     edges: [
#       {
#         edgeIndex: 2,
#         predecessorFactIndex: 2,
#         roleParameter: 4,
#         successorFactIndex: 3
#       }
#     ],
#     existentialConditions: []
#   }
# ]
# ```
#
# To see how nested existential conditions would affect a result query, let's consider a specification that allows a deleted course to be restored.

# %%
[FactType("Course.Restored")]
public record CourseRestored(CourseDeleted deleted) {}

Renderer.RenderTypes(typeof(CourseRestored))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="185pt" height="305pt"
#  viewBox="0.00 0.00 184.78 305.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 301)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-301 180.78,-301 180.78,4 -4,4"/>
# <!-- Course.Restored -->
# <g id="node1" class="node">
# <title>Course.Restored</title>
# <ellipse fill="none" stroke="black" cx="88.39" cy="-18" rx="88.28" ry="18"/>
# <text text-anchor="middle" x="88.39" y="-14.3" font-family="Times,serif" font-size="14.00">Course.Restored</text>
# </g>
# <!-- Course.Deleted -->
# <g id="node2" class="node">
# <title>Course.Deleted</title>
# <ellipse fill="none" stroke="black" cx="88.39" cy="-105" rx="82.59" ry="18"/>
# <text text-anchor="middle" x="88.39" y="-101.3" font-family="Times,serif" font-size="14.00">Course.Deleted</text>
# </g>
# <!-- Course.Restored&#45;&gt;Course.Deleted -->
# <g id="edge1" class="edge">
# <title>Course.Restored&#45;&gt;Course.Deleted</title>
# <path fill="none" stroke="black" d="M88.39,-36.2C88.39,-47.84 88.39,-63.45 88.39,-76.76"/>
# <polygon fill="black" stroke="black" points="84.89,-76.82 88.39,-86.82 91.89,-76.82 84.89,-76.82"/>
# <text text-anchor="middle" x="115.39" y="-57.8" font-family="Times,serif" font-size="14.00">deleted</text>
# </g>
# <!-- Course -->
# <g id="node3" class="node">
# <title>Course</title>
# <ellipse fill="none" stroke="black" cx="88.39" cy="-192" rx="43.59" ry="18"/>
# <text text-anchor="middle" x="88.39" y="-188.3" font-family="Times,serif" font-size="14.00">Course</text>
# </g>
# <!-- Course.Deleted&#45;&gt;Course -->
# <g id="edge2" class="edge">
# <title>Course.Deleted&#45;&gt;Course</title>
# <path fill="none" stroke="black" d="M88.39,-123.2C88.39,-134.84 88.39,-150.45 88.39,-163.76"/>
# <polygon fill="black" stroke="black" points="84.89,-163.82 88.39,-173.82 91.89,-163.82 84.89,-163.82"/>
# <text text-anchor="middle" x="112.39" y="-144.8" font-family="Times,serif" font-size="14.00">course</text>
# </g>
# <!-- School -->
# <g id="node4" class="node">
# <title>School</title>
# <ellipse fill="none" stroke="black" cx="88.39" cy="-279" rx="41.69" ry="18"/>
# <text text-anchor="middle" x="88.39" y="-275.3" font-family="Times,serif" font-size="14.00">School</text>
# </g>
# <!-- Course&#45;&gt;School -->
# <g id="edge3" class="edge">
# <title>Course&#45;&gt;School</title>
# <path fill="none" stroke="black" d="M88.39,-210.2C88.39,-221.84 88.39,-237.45 88.39,-250.76"/>
# <polygon fill="black" stroke="black" points="84.89,-250.82 88.39,-260.82 91.89,-250.82 84.89,-250.82"/>
# <text text-anchor="middle" x="111.39" y="-231.8" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# </g>
# </svg>

# %%
var trigonometryRestored = await j.Fact(new CourseRestored(trigonometryDeleted));

Renderer.RenderFacts(algebra, geometry, trigonometryRestored, calculus)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="748pt" height="349pt"
#  viewBox="0.00 0.00 748.00 349.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 345)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-345 744,-345 744,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="275,-316 275,-337 405,-337 405,-316 275,-316"/>
# <text text-anchor="start" x="316" y="-322.8" font-family="Times,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="275,-295 275,-316 321,-316 321,-295 275,-295"/>
# <text text-anchor="start" x="278" y="-301.8" font-family="Times,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="321,-295 321,-316 405,-316 405,-295 321,-295"/>
# <text text-anchor="start" x="324" y="-301.8" font-family="Times,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="9,-214 9,-235 163,-235 163,-214 9,-214"/>
# <text text-anchor="start" x="60.5" y="-220.8" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="9,-193 9,-214 81,-214 81,-193 9,-193"/>
# <text text-anchor="start" x="12" y="-199.8" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="81,-193 81,-214 163,-214 163,-193 81,-193"/>
# <text text-anchor="start" x="84" y="-199.8" font-family="Times,serif" font-size="14.00">MATH 101</text>
# <polygon fill="none" stroke="black" points="8,-192 8,-236 164,-236 164,-192 8,-192"/>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M149.77,-240.11C186.21,-254.45 231.98,-272.47 269.49,-287.24"/>
# <polygon fill="black" stroke="black" points="268.25,-290.51 278.84,-290.92 270.81,-284 268.25,-290.51"/>
# <text text-anchor="middle" x="252" y="-261.8" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg== -->
# <g id="node3" class="node">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==</title>
# <polygon fill="none" stroke="black" points="199,-214 199,-235 353,-235 353,-214 199,-214"/>
# <text text-anchor="start" x="250.5" y="-220.8" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="199,-193 199,-214 271,-214 271,-193 199,-193"/>
# <text text-anchor="start" x="202" y="-199.8" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="271,-193 271,-214 353,-214 353,-193 271,-193"/>
# <text text-anchor="start" x="274" y="-199.8" font-family="Times,serif" font-size="14.00">MATH 102</text>
# <polygon fill="none" stroke="black" points="198,-192 198,-236 354,-236 354,-192 198,-192"/>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge2" class="edge">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M292.15,-240.23C300.29,-252.95 310.26,-268.54 318.99,-282.18"/>
# <polygon fill="black" stroke="black" points="316.18,-284.27 324.52,-290.81 322.07,-280.5 316.18,-284.27"/>
# <text text-anchor="middle" x="335" y="-261.8" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="node4" class="node">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <polygon fill="none" stroke="black" points="388,-214 388,-235 542,-235 542,-214 388,-214"/>
# <text text-anchor="start" x="439.5" y="-220.8" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="388,-193 388,-214 460,-214 460,-193 388,-193"/>
# <text text-anchor="start" x="391" y="-199.8" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="460,-193 460,-214 542,-214 542,-193 460,-193"/>
# <text text-anchor="start" x="463" y="-199.8" font-family="Times,serif" font-size="14.00">MATH 201</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge3" class="edge">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M434.74,-239.21C417.82,-252.74 396.57,-269.75 378.48,-284.22"/>
# <polygon fill="black" stroke="black" points="376.04,-281.69 370.41,-290.67 380.41,-287.16 376.04,-281.69"/>
# <text text-anchor="middle" x="433" y="-261.8" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- 2WJIRJpw/Jlyydtvqo5g6oKRoJKnZl7l+3kmREeA3Bz4sv0i9e9kT/81T3W6NrwWe5NZseJYa4R9Gh5Qd9RL2A== -->
# <g id="node5" class="node">
# <title>2WJIRJpw/Jlyydtvqo5g6oKRoJKnZl7l+3kmREeA3Bz4sv0i9e9kT/81T3W6NrwWe5NZseJYa4R9Gh5Qd9RL2A==</title>
# <polygon fill="none" stroke="black" points="327,-112 327,-133 604,-133 604,-112 327,-112"/>
# <text text-anchor="start" x="410" y="-118.8" font-family="Times,serif" font-size="14.00">Course.Deleted</text>
# <polygon fill="none" stroke="black" points="327,-91 327,-112 403,-112 403,-91 327,-91"/>
# <text text-anchor="start" x="330" y="-97.8" font-family="Times,serif" font-size="14.00">deletedAt</text>
# <polygon fill="none" stroke="black" points="403,-91 403,-112 604,-112 604,-91 403,-91"/>
# <text text-anchor="start" x="406" y="-97.8" font-family="Times,serif" font-size="14.00">2023&#45;04&#45;02T19:20:11.145Z</text>
# </g>
# <!-- 2WJIRJpw/Jlyydtvqo5g6oKRoJKnZl7l+3kmREeA3Bz4sv0i9e9kT/81T3W6NrwWe5NZseJYa4R9Gh5Qd9RL2A==&#45;&gt;T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="edge4" class="edge">
# <title>2WJIRJpw/Jlyydtvqo5g6oKRoJKnZl7l+3kmREeA3Bz4sv0i9e9kT/81T3W6NrwWe5NZseJYa4R9Gh5Qd9RL2A==&#45;&gt;T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <path fill="none" stroke="black" d="M465,-137.21C465,-149.64 465,-165.01 465,-178.65"/>
# <polygon fill="black" stroke="black" points="461.5,-178.67 465,-188.67 468.5,-178.67 461.5,-178.67"/>
# <text text-anchor="middle" x="489" y="-158.8" font-family="Times,serif" font-size="14.00">course</text>
# </g>
# <!-- j+Bkcs1VS54nRSyzamtzfxVNwxvLuoeVOr+9/OxSq9z13pB3dGCDRXIl8c0uUa/NEJmFddGeb2aH4Jj22CyrBg== -->
# <g id="node6" class="node">
# <title>j+Bkcs1VS54nRSyzamtzfxVNwxvLuoeVOr+9/OxSq9z13

# %%
var coursesInSchoolNotDeletedOrRestored = Given<School>.Match((school, facts) =>
  from course in facts.OfType<Course>()
  where course.school == school
  where !(
    from deleted in facts.OfType<CourseDeleted>()
    where deleted.course == course
    where !facts.OfType<CourseRestored>(restored => restored.deleted == deleted).Any()
    select deleted
  ).Any()
  select course
);

coursesInSchoolNotDeletedOrRestored.ToDescriptiveString()
# Out:
# (school: School) {
#     course: Course [
#         course->school: School = school
#         !E {
#             deleted: Course.Deleted [
#                 deleted->course: Course = course
#                 !E {
#                     restored: Course.Restored [
#                         restored->deleted: Course.Deleted = deleted
#                     ]
#                 }
#             ]
#         }
#     ]
# } => course

# %% [markdown]
# When this specification is run for the school "LPS Frisco", it returns all four courses, since trigonometry has now been restored.

# %%
var catalogNotDeletedOrRestored = await j.Query(lps, coursesInSchoolNotDeletedOrRestored);

catalogNotDeletedOrRestored
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 101 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 101</td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 102 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 102</td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 201 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 201</td></tr></tbody></table></div></details></td></tr><tr><td>3</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 301 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 301</td></tr></tbody></table></div></details></td></tr></tbody></table><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# To translate this specification into SQL, Jinaga allocates edge index 2 for the relationship between `deleted` and `course`.
# Then it allocates fact index 3 for the `deleted` label.
#
# For the nested existential condition, it allocates edge index 3 for the relationship between `restored` and `deleted`.
# Then it allocates fact index 4 for the `restored` label.
#
# This produces the following list in the Query Description.
#
# ```javascript
# existentialConditions: [
#   {
#     exists: false,
#     edges: [
#       {
#         edgeIndex: 2,             // deleted -> course
#         predecessorFactIndex: 2,  // course
#         successorFactIndex: 3,    // deleted
#         roleParameter: 4
#       }
#     ],
#     existentialConditions: [
#       {
#         exists: false,
#         edges: [
#           {
#             edgeIndex: 3,             // restored -> deleted
#             predecessorFactIndex: 3,  // deleted
#             successorFactIndex: 4,    // restored
#             roleParameter: 5
#           }
#         ],
#         existentialConditions: []
#       }
#     ]
#   }
# ]
# ```
#
# That translates into the following condition, which is emitted as part of the `WHERE` clause.
#
# ```sql
# AND NOT EXISTS (
#   SELECT 1
#   FROM edge e2  -- deleted -> course
#   JOIN fact f3  -- deleted
#     ON f3.fact_id = e2.successor_fact_id
#   WHERE e2.predecessor_fact_id = f2.fact_id
#     AND e2.role_id = $4
#   AND NOT EXISTS (
#     SELECT 1
#     FROM edge e3  -- restored -> deleted
#     JOIN fact f4  -- restored
#       ON f4.fact_id = e3.successor_fact_id
#     WHERE e3.predecessor_fact_id = f3.fact_id
#       AND e3.role_id = $5
#   )
# )
# ```
